# %%
import pandas as pd
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./ZyskiFirmyX.csv', sep=',')

# %%
train, test = train_test_split(df, test_size=0.2)
trained_model = sm.OLS(df['Zysk'], df['Rok']).fit()

# %%
print(trained_model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                   Zysk   R-squared (uncentered):                   0.814
# Model:                            OLS   Adj. R-squared (uncentered):              0.813
# Method:                 Least Squares   F-statistic:                              870.1
# Date:                Tue, 17 Jan 2023   Prob (F-statistic):                    1.39e-74
# Time:                        20:24:35   Log-Likelihood:                         -1522.0
# No. Observations:                 200   AIC:                                      3046.
# Df Residuals:                     199   BIC:                                      3049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
plot_data = [[trained_model.predict(year), year] for year in range(1950, 2100)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [40], line 3
#       1 plot_data = [[trained_model.predict(year), year] for year in range(1950, 2100)]
# ----> 3 print(plot_data.shape)
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
predicted_values = [l[0] for l in plot_data]
years = [l[1] for l in plot_data]
plt.plot(years, predicted_values)

# %%
print('Predicted company profit grows in linear manner')
